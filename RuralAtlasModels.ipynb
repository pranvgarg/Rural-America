# %% [markdown]
# We have 81 columns in the dataset. Let's now correctly rename these columns with descriptive names. I'll ensure the new list has 81 elements:
#
# 1. **FIPS:** Federal Information Processing Standards code.
# 2. **State:** State abbreviation.
# 3. **AvgHHSize:** Average household size.
# 4. **Ed1LessThanHSNum:** Number of people with less than high school education.
# 5. **Ed2HSDiplomaOnlyNum:** Number of people with only a high school diploma.
# 6. **Ed3SomeCollegeNum:** Number of people with some college education.
# 7. **Ed4AssocDegreeNum:** Number of people with an associate degree.
# 8. **Ed5CollegePlusNum:** Number of people with college and higher education.
# 9. **FemaleHHNum:** Number of female-headed households.
# 10. **ForeignBornAfricaNum:** Number of foreign-born individuals from Africa.
# 11. **ForeignBornAsiaNum:** Number of foreign-born individuals from Asia.
# 12. **ForeignBornCaribNum:** Number of foreign-born individuals from the Caribbean.
# 13. **ForeignBornCentralSouthAmNum:** Number of foreign-born individuals from Central and South America.
# 14. **ForeignBornEuropeNum:** Number of foreign-born individuals from Europe.
# 15. **ForeignBornMexNum:** Number of foreign-born individuals from Mexico.
# 16. **ForeignBornNum:** Total number of foreign-born individuals.
# 17. **HH65PlusAloneNum:** Number of households with individuals aged 65 and over living alone.
# 18. **NonEnglishHHNum:** Number of non-English speaking households.
# 19. **OwnHomeNum:** Number of owner-occupied homes.
# 20. **OwnHomePct:** Percentage of owner-occupied homes.
# 21. **TotalHH:** Total number of households.
# 22. **TotalOccHU:** Total number of occupied housing units.
# 23. **TotalPop25Plus:** Total population aged 25 and over.
# 24. **TotalPopACS:** Total population according to the American Community Survey (ACS).
# 25. **PctEmpAgriculture:** Percentage of employment in agriculture.
# 26. **PctEmpConstruction:** Percentage of employment in construction.
# 27. **PctEmpFIRE:** Percentage of employment in finance, insurance, and real estate (FIRE).
# 28. **PctEmpInformation:** Percentage of employment in information.
# 29. **PctEmpManufacturing:** Percentage of employment in manufacturing.
# 30. **PctEmpMining:** Percentage of employment in mining.
# 31. **PctEmpGovt:** Percentage of employment in government.
# 32. **PctEmpServices:** Percentage of employment in services.
# 33. **PctEmpTrans:** Percentage of employment in transportation.
# 34. **PctEmpTrade:** Percentage of employment in trade.
# 35. **UnempRate2017:** Unemployment rate for 2017.
# 36. **UnempRate2018:** Unemployment rate for 2018.
# 37. **UnempRate2019:** Unemployment rate for 2019.
# 38. **UnempRate2020:** Unemployment rate for 2020.
# 39. **UnempRate2021:** Unemployment rate for 2021.
# 40. **NumCivLaborforce2017:** Number of civilian labor force for 2017.
# 41. **NumCivLaborforce2018:** Number of civilian labor force for 2018.
# 42. **NumCivLaborforce2019:** Number of civilian labor force for 2019.
# 43. **NumCivLaborforce2020:** Number of civilian labor force for 2020.
# 44. **NumCivLaborforce2021:** Number of civilian labor force for 2021.
# 45. **NumEmployed2017:** Number of employed individuals for 2017.
# 46. **NumEmployed2018:** Number of employed individuals for 2018.
# 47. **NumEmployed2019:** Number of employed individuals for 2019.
# 48. **NumEmployed2020:** Number of employed individuals for 2020.
# 49. **NumEmployed2021:** Number of employed individuals for 2021.
# 50. **NumUnemployed2017:** Number of unemployed individuals for 2017.
# 51. **NumUnemployed2018:** Number of unemployed individuals for 2018.
# 52. **NumUnemployed2019:** Number of unemployed individuals for 2019.
# 53. **NumUnemployed2020:** Number of unemployed individuals for 2020.
# 54. **NumUnemployed2021:** Number of unemployed individuals for 2021.
# 55. **Deep_Pov_Children:** Number of children in deep poverty.
# 56. **Deep_Pov_All:** Number of people in deep poverty.
# 57. **Median_HH_Inc_ACS:** Median household income according to ACS.
# 58. **PerCapitaInc:** Per capita income.
# 59. **Poverty_Rate_0_17_ACS:** Poverty rate for ages 0-17 according to ACS.
# 60. **Poverty_Rate_ACS:** Poverty rate according to ACS.
# 61. **MedHHInc:** Median household income.
# 62. **POV017:** Number of people aged 0-17 in poverty.
# 63. **NumAll_inPOV_ACS:** Number of people in poverty according to ACS.
# 64. **POVALL:** Number of people in poverty.
# 65. **PCTPOV017:** Percentage of people aged 0-17 in poverty.
# 66. **PCTPOVALL:** Percentage of people in poverty.
# 67. **Num_inPOV_0_17_ACS:** Number of people aged 0-17 in poverty according to ACS.
# 68. **FemaleHHRatio:** Female household ratio.
# 69. **ForeignBornHHRatio:** Foreign-born household ratio.
# 70. **ForeignBornRatio:** Foreign-born ratio.
# 71. **OwnHomeRatio:** Owner-occupied home ratio.
# 72. **TotalForeignBorn:** Total foreign-born population.
# 73. **TotalEducationAttainment:** Total education attainment.
# 74. **HomeOwnership_Education:** Home ownership based on education.
# 75. **Employment_Education:** Employment based on education.
# 76. **LogHHIncome:** Logarithm of household income.
# 77. **Ed1LessThanHS_perCapita:** Per capita number of people with less than high school education.
# 78. **Ed2HSDiplomaOnly_perCapita:** Per capita number of people with only a high school diploma.
# 79. **Ed3SomeCollege_perCapita:** Per capita number of people with some college education.
# 80. **Ed4AssocDegree_perCapita:** Per capita number of people with an associate degree.
# 81. **Ed5CollegePlus_perCapita:** Per capita number of people with college and higher education.
#
# Let's rename the columns accordingly.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import folium
import matplotlib.pyplot as plt
import seaborn as sns # Import seaborn for heatmap plotting
from folium.plugins import HeatMap
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import warnings
import requests
warnings.filterwarnings('ignore')

# %%
jobs = pd.read_csv('Jobs.csv', encoding_errors = "ignore")
income = pd.read_csv('Income.csv', encoding_errors = "ignore")
veterans = pd.read_csv('Veterans.csv', encoding_errors = "ignore")
people = pd.read_csv('People.csv', encoding_errors = "ignore")

# %%
print("="*40)
print("All Dataframe Info")
print("="*40)
print("="*40)
print("jobs Info")
print("="*40)
print(jobs.info())
print("="*40)
print("income Info")
print("="*40)
print(income.info())
print("="*40)
print("veterans Info")
print("="*40)
print(veterans.info())
print("="*40)
print("people Info")
print("="*40)
print(people.info())
print("="*40)
# Out:
# ========================================
# All Dataframe Info
# ========================================
# ========================================
# jobs Info
# ========================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3280 entries, 0 to 3279
# Data columns (total 79 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   FIPS                  3280 non-null   int64
#  1   State                 3280 non-null   object
#  2   County                3280 non-null   object
#  3   UnempRate2021         3273 non-null   float64
#  4   PctEmpChange2021      3194 non-null   float64
#  5   UnempRate2020         3194 non-null   float64
#  6   PctEmpChange1920      3192 non-null   float64
#  7   UnempRate2019         3272 non-null   float64
#  8   UnempRate2018         3272 non-null   float64
#  9   UnempRate2017         3272 non-null   float64
#  10  UnempRate2016         3272 non-null   float64
#  11  UnempRate2015         3272 non-null   float64
#  12  UnempRate2010         3272 non-null   float64
#  13  UnempRate2007         3270 non-null   float64
#  14  PctEmpChange1021      3271 non-null   float64
#  15  PctEmpChange0721      3266 non-null   float64
#  16  PctEmpChange0710      3267 non-null   float64
#  17  PctEmpAgriculture     3274 non-null   float64
#  18  PctEmpMining          3274 non-null   float64
#  19  PctEmpConstruction    3274 non-null   float64
#  20  PctEmpManufacturing   3274 non-null   float64
#  21  PctEmpTrade           3274 non-null   float64
#  22  PctEmpTrans           3274 non-null   float64
#  23  PctEmpInformation     3274 non-null   float64
#  24  PctEmpFIRE            3274 non-null   float64
#  25  PctEmpServices        3274 non-null   float64
#  26  PctEmpGovt            3274 non-null   float64
#  27  NumCivEmployed        3274 non-null   float64
#  28  NumCivLaborForce2008  3270 non-null   float64
#  29  NumUnemployed2012     3272 non-null   float64
#  30  NumEmployed2012       3272 non-null   float64
#  31  UnempRate2012         3272 non-null   float64
#  32  NumCivLaborForce2012  3272 non-null   float64
#  33  UnempRate2009         3270 non-null   float64
#  34  NumUnemployed2011     3272 non-null   float64
#  35  NumCivLaborForce2009  3270 non-null   float64
#  36  NumCivLaborForce2011  3272 non-null   float64
#  37  NumEmployed2014       3272 non-null   float64
#  38  NumEmployed2008       3270 non-null   float64
#  39  UnempRate2011         3272 non-null   float64
#  40  NumUnemployed2020     3194 non-null   float64
#  41  NumEmployed2020       3194 non-null   float64
#  42  NumCivLaborForce2020  3194 non-null   float64
#  43  NumUnemployed2008     3270 non-null   float64
#  44  NumUnemployed2009     3270 non-null   float64
#  45  NumEmployed2009       3270 non-null   float64
#  46  NumCivLaborforce2007  3270 non-null   float64
#  47  UnempRate2008         3270 non-null   float64
#  48  NumEmployed2011       3272 non-null   float64
#  49  NumCivLaborforce2017  3272 non-null   float64
#  50  NumUnemployed2021     3273 non-null   float64
#  51  NumEmployed2021       3273 non-null   float64
#  52  NumCivLaborforce2021  3273 non-null   float64
#  53  NumEmployed2010       3272 non-null   float64
#  54  NumCivLaborforce2010  3272 non-null   float64
#  55  NumUnemployed2010     3272 non-null   float64
#  56  NumEmployed2019       3272 non-null   float64
#  57  NumUnemployed2019     3272 non-null   float64
#  58  NumCivLaborforce2019  3272 non-null   float64
#  59  NumUnemployed2018     3272 non-null   float64
#  60  NumEmployed2018       3272 non-null   float64
#  61  NumCivLaborforce2018  3272 non-null   float64
#  62  UnempRate2013         3272 non-null   float64
#  63  NumEmployed2017       3272 non-null   float64
#  64  NumEmployed2007       3270 non-null   float64
#  65  NumUnemployed2016     3272 non-null   float64
#  66  NumEmployed2016       3272 non-null   float64
#  67  NumCivLaborforce2016  3272 non-null   float64
#  68  NumCivLaborforce2015  3272 non-null   float64
#  69  NumEmployed2015       3272 non-null   float64
#  70  NumUnemployed2015     3272 non-null   float64
#  71  UnempRate2014         3272 non-null   float64
#  72  NumUnemployed2014     3272 non-null   float64
#  73  NumCivLaborforce2014  3272 non-null   float64
#  74  NumUnemployed2013     3272 non-null   float64
#  75  NumEmployed2013       3272 non-null   float64
#  76  NumCivLaborforce2013  3272 non-null   float64
#  77  NumUnemployed2007     3270 non-null   float64
#  78  NumUnemployed2017     3272 non-null   float64
# dtypes: float64(76), int64(1), object(2)
# memory usage: 2.0+ MB
# None
# ========================================
# income Info
# ========================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3280 entries, 0 to 3279
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FIPS                   3280 non-null   int64
#  1   State                  3280 non-null   object
#  2   County                 3280 non-null   object
#  3   Median_HH_Inc_ACS      3273 non-null   float64
#  4   PerCapitaInc           3274 non-null   float64
#  5   Poverty_Rate_0_17_ACS  3273 non-null   float64
#  6   Poverty_Rate_ACS       3274 non-null   float64
#  7   Deep_Pov_All           3274 non-null   float64
#  8   Deep_Pov_Children      3274 non-null   float64
#  9   NumAll_inPOV_ACS       3274 non-null   float64
#  10  PCTPOV017              3194 non-null   float64
#  11  POV017                 3194 non-null   float64
#  12  MedHHInc               3194 non-null   float64
#  13  POVALL                 3194 non-null   float64
#  14  PCTPOVALL              3194 non-null   float64
#  15  Num_inPOV_0_17_ACS     3274 non-null   float64
# dtypes: float64(13), int64(1), object(2)
# memory usage: 410.1+ KB
# None
# ========================================
# veterans Info
# ========================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3280 entries, 0 to 3279
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   FIPS                  3280 non-null   int64
#  1   State                 3280 non-null   object
#  2   County                3280 non-null   object
#  3   Vets18OPct            3274 non-null   float64
#  4   GulfWar2VetsPct       3195 non-null   float64
#  5   GulfWar1VetsPct       3195 non-null   float64
#  6   VietnamEraVetsPct     3195 non-null   float64
#  7   KoreanWarVetsPct      3195 non-null   float64
#  8   WW2VetsPct            3195 non-null   float64
#  9   MaleVetsPct           3274 non-null   float64
#  10  FemaleVetsPct         3274 non-null   float64
#  11  WhiteNonHispVetsPct   3274 non-null   float64
#  12  BlackVetsPct          3274 non-null   float64
#  13  HispanicVetsPct       3274 non-null   float64
#  14  OtherRaceVetsPct      3274 non-null   float64
#  15  MedianVetsInc         3232 non-null   float64
#  16  MedianNonVetsInc      3274 non-null   float64
#  17  LessThanHSVetsPct     3274 non-null   float64
#  18  HighSchOnlyVetsPct    3274 non-null   float64
#  19  SomeCollegeVetsPct    3274 non-null   float64
#  20  CollegeDegreeVetsPct  3274 non-null   float64
#  21  LFPVetsRate           3270 non-null   float64
#  22  UEVetsRate            3274 non-null   float64
#  23  PctVetsPoor           3269 non-null   float64
#  24  PctNonVetsPoor        3274 non-null   float64
#  25  PctVetsDisabilty      3269 non-null   float64
#  26  PctNonVetsDisabilty   3274 non-null   float64
#  27  CivPopVets18to64Num   3274 non-null   float64
#  28  CivPop18ONum          3274 non-null   float64
#  29  Vets18ONum            3274 non-null   float64
#  30  NonVetsDisabilty      3274 non-null   float64
#  31  NonVetsPoor           3274 non-null   float64
#  32  VetsDisabilty         3274 non-null   float64
#  33  VetsPoor              3274 non-null   float64
#  34  CLFVets18to64Num      3274 non-null   float64
# dtypes: float64(32), int64(1), object(2)
# memory usage: 897.0+ KB
# None
# ========================================
# people Info
# ========================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3280 entries, 0 to 3279
# Data columns (total 94 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   FIPS                                        3280 non-null   int64
#  1   State                                       3280 non-null   object
#  2   County                                      3280 non-null   object
#  3   Pop_change_Rate_2020_2021                   3195 non-null   float64
#  4   POPESTIMATE2021                             3274 non-null   float64
#  5   Net_Migration_Rate_2020_2021                3195 non-null   float64
#  6   Natural_Change_Rate_2020_2021               3195 non-null   float64
#  7   Net_InterMigrationRate_2020_2021            3195 non-null   float64
#  8   PopChangeRate1020                           3271 non-null   float64
#  9   PopDensity2020                              3274 non-null   float64
#  10  Under18Pct2020                              3274 non-null   float64
#  11  Age65AndOlderPct2020                        3195 non-null   float64
#  12  WhiteNonHispanicPct2020                     3274 non-null   float64
#  13  BlackNonHispanicPct2020                     3274 non-null   float64
#  14  AsianNonHispanicPct2020                     3274 non-null   float64
#  15  NativeAmericanNonHispanicPct2020            3274 non-null   float64
#  16  HispanicPct2020                             3274 non-null   float64
#  17  MultipleRacePct2020                         3274 non-null   float64
#  18  NonHispWhitePopChangeRate1020               3271 non-null   float64
#  19  NonHispBlackPopChangeRate1020               3237 non-null   float64
#  20  NonHispAsianPopChangeRate1020               3248 non-null   float64
#  21  NonHispNatAmerPopChangeRate1020             3244 non-null   float64
#  22  HispanicPopChangeRate1020                   3270 non-null   float64
#  23  MultipleRacePopChangeRate1020               3271 non-null   float64
#  24  WhiteNonHispanicNum2020                     3274 non-null   float64
#  25  BlackNonHispanicNum2020                     3274 non-null   float64
#  26  AsianNonHispanicNum2020                     3274 non-null   float64
#  27  NativeAmericanNonHispanicNum2020            3274 non-null   float64
#  28  HispanicNum2020                             3274 non-null   float64
#  29  MultipleRaceNum2020                         3274 non-null   float64
#  30  ForeignBornPct                              3195 non-null   float64
#  31  ForeignBornEuropePct                        3195 non-null   float64
#  32  ForeignBornMexPct                           3195 non-null   float64
#  33  NonEnglishHHPct                             3274 non-null   float64
#  34  Ed1LessThanHSPct                            3274 non-null   float64
#  35  Ed2HSDiplomaOnlyPct                         3274 non-null   float64
#  36  Ed3SomeCollegePct                           3274 non-null   float64
#  37  Ed4AssocDegreePct                           3274 non-null   float64
#  38  Ed5CollegePlusPct                           3274 non-null   float64
#  39  AvgHHSize                                   3274 non-null   float64
#  40  FemaleHHPct                                 3274 non-null   float64
#  41  HH65PlusAlonePct                            3274 non-null   float64
#  42  OwnHomePct                                  3274 non-null   float64
#  43  Ed3SomeCollegeNum                           3274 non-null   float64
#  44  Ed2HSDiplomaOnlyNum                         3274 non-null   float64
#  45  Ed1LessThanHSNum                            3274 non-null   float64
#  46  TotalPopACS                                 3274 non-null   float64
#  47  ForeignBornNum                              3195 non-null   float64
#  48  TotalPop25Plus                              3274 non-null   float64
#  49  ForeignBornEuropeNum                        3195 non-null   float64
#  50  ForeignBornCaribNum                         3195 non-null   float64
#  51  ForeignBornMexNum                           3195 non-null   float64
#  52  Ed5CollegePlusNum                           3274 non-null   float64
#  53  HH65PlusAloneNum                            3274 non-null   float64
#  54  Ed4AssocDegreeNum                           3274 non-null   float64
#  55  ForeignBornAfricaNum                        3195 non-null   float64
#  56  ForeignBornAsiaNum                          3195 non-null   float64
#  57  NonEnglishHHNum                             3274 non-null   float64
#  58  OwnHomeNum                                  3274 non-null   float64
#  59  FemaleHHNum                                 3274 non-null   float64
#  60  TotalHH                                     3274 non-null   float64
#  61  ForeignBornCentralSouthAmPct                3195 non-null   float64
#  62  ForeignBornCentralSouthAmNum                3195 non-null   float64
#  63  ForeignBornCaribPct                         3195 non-null   float64
#  64  ForeignBornAsiaPct                          3195 non-null   float64
#  65  TotalOccHU                                  3274 non-null   float64
#  66  ForeignBornAfricaPct                        3195 non-null   float64
#  67  Age65AndOlderNum2020                        3195 non-null   float64
#  68  Under18Num2020                              3274 non-null   float64
#  69  LandAreaSQMiles2020                         3274 non-null   float64
#  70  TotalPop2020                                3274 non-null   float64
#  71  NaturalChange1019                           3194 non-null   float64
#  72  TotalPopEst2015                             3272 non-null   float64
#  73  TotalPopEst2016                             3272 non-null   float64
#  74  TotalPopEst2017                             3272 non-null   float64
#  75  TotalPopEst2018                             3272 non-null   float64
#  76  Net_International_Migration_2010_2019       3194 non-null   float64
#  77  TotalPopEst2019                             3272 non-null   float64
#  78  TotalPopEst2012                             3272 non-null   float64
#  79  NetMigration1019                            3194 non-null   float64
#  80  Net_International_Migration_Rate_2010_2019  3194 non-null   float64
#  81  NaturalChangeRate1019                       3194 non-null   float64
#  82  NetMigrationRate1019                        3194 non-null   float64
#  83  PopChangeRate1019                           3272 non-null   float64
#  84  TotalPopEst2014                             3272 non-null   float64
#  85  TotalPopEst2013                             3272 non-null   float64
#  86  TotalPopEstBase2010                         3272 non-null   float64
#  87  TotalPopEst2011                             3272 non-null   float64
#  88  TotalPopEst2010                             3272 non-null   float64
#  89  ESTIMATESBASE2020                           3274 non-null   float64
#  90  POPESTIMATE2020                             3274 non-null   float64
#  91  NaturalChg2020_2021                         3195 non-null   float64
#  92  Net_InterMigration_2020_2021                3195 non-null   float64
#  93  Net_Migration_2020_2021                     3195 non-null   float64
# dtypes: float64(91), int64(1), object(2)
# memory usage: 2.4+ MB
# None
# ========================================

# %%
print("="*40, "JOBS", jobs.shape, "="*40)
print(jobs.isna().sum())
print("="*40, "INCOME", income.shape, "="*40)
print(income.isna().sum())
print("="*40, "VETERANs", veterans.shape, "="*40)
print(veterans.isna().sum())
print("="*40, "PEOPLE", people.shape, "="*40)
print(people.isna().sum())
print("="*40)
# Out:
# ======================================== JOBS (3280, 79) ========================================
# FIPS                     0
# State                    0
# County                   0
# UnempRate2021            7
# PctEmpChange2021        86
#                         ..
# NumUnemployed2013        8
# NumEmployed2013          8
# NumCivLaborforce2013     8
# NumUnemployed2007       10
# NumUnemployed2017        8
# Length: 79, dtype: int64
# ======================================== INCOME (3280, 16) ========================================
# FIPS                      0
# State                     0
# County                    0
# Median_HH_Inc_ACS         7
# PerCapitaInc              6
# Poverty_Rate_0_17_ACS     7
# Poverty_Rate_ACS          6
# Deep_Pov_All              6
# Deep_Pov_Children         6
# NumAll_inPOV_ACS          6
# PCTPOV017                86
# POV017                   86
# MedHHInc                 86
# POVALL                   86
# PCTPOVALL                86
# Num_inPOV_0_17_ACS        6
# dtype: int64
# ======================================== VETERANs (3280, 35) ========================================
# FIPS                     0
# State                    0
# County                   0
# Vets18OPct               6
# GulfWar2VetsPct         85
# GulfWar1VetsPct         85
# VietnamEraVetsPct       85
# KoreanWarVetsPct        85
# WW2VetsPct              85
# MaleVetsPct              6
# FemaleVetsPct            6
# WhiteNonHispVetsPct      6
# BlackVetsPct             6
# HispanicVetsPct          6
# OtherRaceVetsPct         6
# MedianVetsInc           48
# MedianNonVetsInc         6
# LessThanHSVetsPct        6
# HighSchOnlyVetsPct       6
# SomeCollegeVetsPct       6
# CollegeDegreeVetsPct     6
# LFPVetsRate             10
# UEVetsRate               6
# PctVetsPoor             11
# PctNonVetsPoor           6
# PctVetsDisabilty        11
# PctNonVetsDisabilty      6
# CivPopVets18to64Num      6
# CivPop18ONum             6
# Vets18ONum               6
# NonVetsDisabilty         6
# NonVetsPoor              6
# VetsDisabilty            6
# VetsPoor                 6
# CLFVets18to64Num         6
# dtype: int64
# ======================================== PEOPLE (3280, 94) ========================================
# FIPS                             0
# State                            0
# County                           0
# Pop_change_Rate_2020_2021       85
# POPESTIMATE2021                  6
#                                 ..
# ESTIMATESBASE2020                6
# POPESTIMATE2020                  6
# NaturalChg2020_2021             85
# Net_InterMigration_2020_2021    85
# Net_Migration_2020_2021         85
# Length: 94, dtype: int64
# ========================================

# %%
master_df = pd.merge(jobs,income, on=['FIPS','State','County'], how='inner')
master_df = pd.merge(master_df, people, on=['FIPS','State','County'], how='inner')
master_df = pd.merge(master_df, veterans, on=['FIPS','State','County'], how='inner')
variable_names = [
    "FIPS",
    "State",
    "County",
    "AvgHHSize",
    "Ed1LessThanHSNum",
    "Ed2HSDiplomaOnlyNum",
    "Ed3SomeCollegeNum",
    "Ed4AssocDegreeNum",
    "Ed5CollegePlusNum",
    "FemaleHHNum",
    "ForeignBornAfricaNum",
    "ForeignBornAsiaNum",
    "ForeignBornCaribNum",
    "ForeignBornCentralSouthAmNum",
    "ForeignBornEuropeNum",
    "ForeignBornMexNum",
    "ForeignBornNum",
    "HH65PlusAloneNum",
    "NonEnglishHHNum",
    "OwnHomeNum",
    "OwnHomePct",
    "TotalHH",
    "TotalOccHU",
    "TotalPop25Plus",
    "TotalPopACS",
    "PctEmpAgriculture",
    "PctEmpConstruction",
    "PctEmpFIRE",
    "PctEmpInformation",
    "PctEmpManufacturing",
    "PctEmpMining",
    "PctEmpGovt",
    "PctEmpServices",
    "PctEmpTrans",
    "PctEmpTrade",
    "UnempRate2017",
    "UnempRate2018",
    "UnempRate2019",
    "UnempRate2020",
    "UnempRate2021",
    "NumCivEmployed",
    "NumCivLaborforce2017",
    "NumCivLaborforce2018",
    "NumCivLaborforce2019",
    "NumCivLaborForce2020",
    "NumCivLaborforce2021",
    "NumEmployed2017",
    "NumEmployed2018",
    "NumEmployed2019",
    "NumEmployed2020",
    "NumEmployed2021",
    "NumUnemployed2017",
    "NumUnemployed2018",
    "NumUnemployed2019",
    "NumUnemployed2020",
    "NumUnemployed2021",
    "Deep_Pov_Children",
    "Deep_Pov_All",
    "Median_HH_Inc_ACS",
    "PerCapitaInc",
    "Poverty_Rate_0_17_ACS",
    "Poverty_Rate_ACS",
    "MedHHInc",
    "POV017",
    "NumAll_inPOV_ACS",
    "POVALL",
    "PCTPOV017",
    "PCTPOVALL",
    "Num_inPOV_0_17_ACS",
    "MedianVetsInc",
    "MedianNonVetsInc",
    "LessThanHSVetsPct",
    "HighSchOnlyVetsPct",
    "SomeCollegeVetsPct",
    "CollegeDegreeVetsPct",
    "LFPVetsRate",
    "UEVetsRate",
    "PctVetsPoor",
    "PctNonVetsPoor",
    "PctVetsDisabilty",
    "PctNonVetsDisabilty",
    "CivPopVets18to64Num",
    "CivPop18ONum",
    "Vets18ONum",
    "NonVetsDisabilty",
    "NonVetsPoor",
    "VetsDisabilty",
    "VetsPoor",
    "CLFVets18to64Num",
]

master_df.shape
# Out:
# (3279, 215)

# %%
#keep track of the rows with missing data
rows_with_na = master_df[master_df.isna().any(axis=1)]
rows_with_na
# Drop rows with infinite or NaN values resulting from division
master_df.replace([np.inf, -np.inf], np.nan, inplace=True)
master_df.dropna(inplace=True)

# %%
clean_df = master_df[variable_names].copy()
print(clean_df.isna().sum())
# makeing a new dataframe with only the FIPS, State, and County
stateCountyIds = clean_df[["FIPS", "State", "County"]].copy()
# removing the NumCivEmployed column from the original clean dataframe
clean_df.drop(columns=['NumCivEmployed', 'County'],axis = 1, inplace=True)
# Out:
# FIPS                0
# State               0
# County              0
# AvgHHSize           0
# Ed1LessThanHSNum    0
#                    ..
# NonVetsDisabilty    0
# NonVetsPoor         0
# VetsDisabilty       0
# VetsPoor            0
# CLFVets18to64Num    0
# Length: 89, dtype: int64

# %%
# Feature Engineering

clean_df['FemaleHHRatio'] = clean_df['FemaleHHNum'] / clean_df['TotalHH']
clean_df['ForeignBornHHRatio'] = clean_df['ForeignBornNum'] / clean_df['TotalHH']
clean_df['ForeignBornRatio'] = clean_df['ForeignBornNum'] / clean_df['TotalPopACS']
clean_df['OwnHomeRatio'] = clean_df['OwnHomeNum'] / clean_df['TotalOccHU']
clean_df['TotalForeignBorn'] = clean_df[['ForeignBornAfricaNum', 'ForeignBornAsiaNum', 'ForeignBornCaribNum',
                             'ForeignBornCentralSouthAmNum', 'ForeignBornEuropeNum', 'ForeignBornMexNum']].sum(axis=1)
clean_df['TotalEducationAttainment'] = clean_df[['Ed1LessThanHSNum', 'Ed2HSDiplomaOnlyNum', 'Ed3SomeCollegeNum',
                                     'Ed4AssocDegreeNum', 'Ed5CollegePlusNum']].sum(axis=1)
clean_df['HomeOwnership_Education'] = clean_df['OwnHomePct'] * clean_df['Ed5CollegePlusNum']
clean_df['Employment_Education'] = clean_df['NumEmployed2021'] * clean_df['Ed5CollegePlusNum']
clean_df['LogHHIncome'] = np.log(clean_df['Median_HH_Inc_ACS'])

clean_df['Ed1LessThanHS_perCapita'] = clean_df['Ed1LessThanHSNum'] / clean_df['TotalEducationAttainment']
clean_df['Ed2HSDiplomaOnly_perCapita'] = clean_df['Ed2HSDiplomaOnlyNum'] / clean_df['TotalEducationAttainment']
clean_df['Ed3SomeCollege_perCapita'] = clean_df['Ed3SomeCollegeNum'] / clean_df['TotalEducationAttainment']
clean_df['Ed4AssocDegree_perCapita'] = clean_df['Ed4AssocDegreeNum'] / clean_df['TotalEducationAttainment']
clean_df['Ed5CollegePlus_perCapita'] = clean_df['Ed5CollegePlusNum'] / clean_df['TotalEducationAttainment']
clean_df['EduAttainmentRatio'] = (clean_df['Ed3SomeCollegeNum'] + clean_df['Ed4AssocDegreeNum'] + clean_df['Ed5CollegePlusNum']) / (clean_df['Ed1LessThanHSNum'] + clean_df['Ed2HSDiplomaOnlyNum'])

clean_df['AvgNumEmployed2017_2021'] = clean_df[['NumEmployed2017', 'NumEmployed2018', 'NumEmployed2019', 'NumEmployed2020', 'NumEmployed2021']].mean(axis=1)
clean_df['AvgNumUnemployed2017_2021'] = clean_df[['NumUnemployed2017', 'NumUnemployed2018', 'NumUnemployed2019', 'NumUnemployed2020', 'NumUnemployed2021']].mean(axis=1)

clean_df['VetsDisabilityIndex'] = clean_df['PctVetsDisabilty']+clean_df['PctNonVetsDisabilty']/2
clean_df['HomeEduInteraction'] = (clean_df['OwnHomeNum'] / clean_df['TotalHH']) * ((clean_df['Ed3SomeCollegeNum'] + clean_df['Ed4AssocDegreeNum'] + clean_df['Ed5CollegePlusNum']) / clean_df['TotalPop25Plus'])

clean_df.shape

# 'VetsDisabilityIndex', 'HomeEduInteraction', 'EduAttainmentRatio'
# Out:
# (3106, 106)

# %%
clean_df.rename(columns={
    "Deep_Pov_Children": "NumDeepPovChildren",
    "Deep_Pov_All": "NumDeepPovAll",
    "Median_HH_Inc_ACS": "MedianHHIncomeACS", #drop this
    "PerCapitaInc": "PerCapitaIncome",
    "Poverty_Rate_0_17_ACS": "PovertyRate0to17ACS",
    "Poverty_Rate_ACS": "PovertyRateACS",
    "MedHHInc": "MedianHHIncome", #drop this
    "POV017": "NumPoverty0to17",
    "NumAll_inPOV_ACS": "NumAllPovertyACS",
    "POVALL": "NumAllPoverty",
    "PCTPOV017": "PercentPoverty0to17",
    "PCTPOVALL": "PercentPovertyAll",
    "Num_inPOV_0_17_ACS": "NumPoverty0to17ACS",
    'TotalHH': 'TotalHouseholds',
    'TotalOccHU': 'TotalOccupiedHousingUnits',
    'TotalPop25Plus': 'TotalPopulation25Plus',
    'TotalPopACS': 'TotalPopulationACS'
}, inplace=True)

# %%
# prompt: give me the name of columns in df which are not numerical

non_numeric_columns = clean_df.select_dtypes(exclude=['number']).columns
print(non_numeric_columns)
# Out:
# Index(['State'], dtype='object')

# %%
# removing the income columns/features -> 'MedianHHIncomeACS', 'MedianHHIncome',"MedianNonVetsInc","PerCapitaIncome","MedianVetsInc"
clean_df.drop(columns=['MedianHHIncomeACS', 'MedianHHIncome', 'MedianVetsInc', 'MedianNonVetsInc', 'PerCapitaIncome','MedianVetsInc'], inplace=True)
clean_df.shape
# Out:
# (3106, 101)

# %%
# Export the DataFrame to a CSV file
#clean_df.to_csv('clean_df.csv', index=False)

# %%
clean_df.describe()
# Out:
#                FIPS    AvgHHSize  Ed1LessThanHSNum  Ed2HSDiplomaOnlyNum  \
# count   3106.000000  3106.000000      3.106000e+03         3.106000e+03
# mean   30290.324855     2.542415      2.418762e+04         5.758484e+04
# std    15155.271629     0.251615      4.641317e+05         1.091179e+06
# min        0.000000     1.920000      1.400000e+01         8.900000e+01
# 25%    18163.500000     2.390000      9.740000e+02         3.068750e+03
# 50%    29138.000000     2.510000      2.369500e+03         6.885000e+03
# 75%    45048.500000     2.650000      5.618000e+03         1.675150e+04
# max    56045.000000     5.240000      2.505036e+07         5.963639e+07
#
#        Ed3SomeCollegeNum  Ed4AssocDegreeNum  Ed5CollegePlusNum   FemaleHHNum  \
# count       3.106000e+03       3.106000e+03       3.106000e+03  3.106000e+03
# mean        4.349404e+04       1.894128e+04       7.321292e+04  1.474929e+04
# std         8.260886e+05       3.593753e+05       1.392415e+06  2.804246e+05
# min         6.800000e+01       1.000000e+00       4.000000e+01  2.000000e+00
# 25%         1.759250e+03       7.235000e+02       1.408000e+03  4.612500e+02
# 50%         3.976000e+03       1.778500e+03       3.782500e+03  1.173000e+03
# 75%         1.127125e+04       5.251750e+03       1.314275e+04  3.306000e+03
# max         4.504203e+07       1.961471e+07       7.580883e+07  1.527328e+07
#
#        ForeignBornAfricaNum  ForeignBornAsiaNum  ...  Ed1LessThanHS_perCapita  \
# count          3.106000e+03        3.106000e+03  ...              3106.000000
# mean           2.392808e+03        1.349228e+04  ...                 0.119796
# std            4.573821e+04        2.666977e+05  ...                 0.056918
# min            0.000000e+00        0.000000e+00  ...                 0.013798
# 25%            0.000000e+00        3.200000e+01  ...                 0.077115
# 50%            1.400000e+01        1.310000e+02  ...                 0.107677
# 75%            1.327500e+02        7.265000e+02  ...                 0.151699
# max            2.477515e+06        1.396957e+07  ...                 0.434409
#
#        Ed2HSDiplomaOnly_perCapita  Ed3SomeCollege_perCapita  \
# count                 3106.000000               3106.000000
# mean                     0.338909                  0.214070
# std                      0.075119                  0.037636
# min                      0.065471                  0.073346
# 25%                      0.291232                  0.189696
# 50%                      0.341106                  0.212828
# 75%                      0.392287                  0.237815
# max                      0.533934                  0.365613
#
#        Ed4AssocDegree_perCapita  Ed5CollegePlus_perCapita  EduAttainmentRatio  \
# count               3106.000000               3106.000000         3106.000000
# mean                   0.094798                  0.232427            1.331014
# std                    0.027709                  0.100032            0.709371
# min                    0.000655                  0.063849            0.311298
# 25%                    0.076246                  0.162059            0.865651
# 50%                    0.092011                  0.207146            1.173202
# 75%                    0.111114                  0.279383            1.600770
# max                    0.225570                  0.786988            9.832408
#
#        AvgNumEmployed2017_2021  AvgNumUnemployed2017_2021  \
# count             3.106000e+03               3.106000e+03
# mean              1.484354e+05               7.919215e+03
# std               2.818936e+06               1.510270e+05
# min               2.434000e+02               1.220000e+01
# 25%               5.070050e+03               2.540500e+02
# 50%               1.199270e+04               6.109000e+02
# 75%               3.430250e+04               1.756000e+03
# max               1.537121e+08               8.200945e+06
#
#        VetsDisabilityIndex  HomeEduInteraction
# count          3106.000000         3106.000000
# mean             28.562766            0.390628
# std              12.136452            0.084332
# min               1.543374            0.091815
# 25%              20.573299            0.331167
# 50%              26.820298            0.389284
# 75%              34.673651            0.446447
# max             104.700855            0.699546
#
# [8 rows x 100 columns]

# %%
# prompt: num of cols in rows_with_na

rows_with_na.shape  #rowns, cols
# Out:
# (173, 215)

# %% [markdown]
# So, we have 4 dataframes now:
# 1. master_df - with all the needed columns
# 2. clean_df - removing the NumCivEmployed, State, County
# 3. stateCountyIds = clean_df[["FIPS", "State", "County"]].copy()
# 4. rows_with_na - tracking of removed rows
#
# # Using only clean_df now as df

# %%
# these are the feature column
featuresColumns = [
    'VetsDisabilityIndex', 'HomeEduInteraction', 'EduAttainmentRatio',
    "PercentPoverty0to17",
    "PovertyRateACS",
    "PctNonVetsPoor",
    "PercentPovertyAll",
    "Ed5CollegePlus_perCapita",
    "PctNonVetsDisabilty",
    "PctEmpAgriculture",
    "ForeignBornHHRatio",
    "AvgHHSize",
    "HomeOwnership_Education",
    "ForeignBornEuropeNum",
    "ForeignBornAsiaNum",
    "ForeignBornNum",
    "CollegeDegreeVetsPct",
    "Ed4AssocDegree_perCapita",
    "PctEmpGovt",
    "ForeignBornRatio",
    "ForeignBornCaribNum",
    "LFPVetsRate",
    "PctEmpManufacturing",
    "HighSchOnlyVetsPct",
    "PctEmpTrade",
    "PctEmpInformation",
    "PovertyRate0to17ACS",
    "Ed2HSDiplomaOnly_perCapita",
    "PctEmpFIRE",
    "PctEmpMining",
    "Ed3SomeCollege_perCapita",
    "CLFVets18to64Num",
    "FIPS",
    "LogHHIncome",
    "FemaleHHRatio",
    "OwnHomeRatio",
    "TotalForeignBorn",
    "TotalEducationAttainment",
    "Employment_Education",
    "Ed1LessThanHS_perCapita",
    "AvgNumEmployed2017_2021",
    "AvgNumUnemployed2017_2021",
    "State"
]

# %%
clean_df.drop(index=0, inplace=True)
df = clean_df.copy() # we can use only featured columns as well here df = clean_df['featuresColumns'].copy()

# %%
df_x = df.drop(['LogHHIncome', 'FIPS', 'State'], axis=1)
df_y = df['LogHHIncome']

# %%
# prompt: standardize on df using standard scaler for sklearn

import pandas as pd
from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler to your data and transform it
scaled_data = scaler.fit_transform(df_x)

# Create a new DataFrame with the scaled data
scaled_df = pd.DataFrame(scaled_data, columns=df_x.columns)
reversed_df = pd.DataFrame(scaler.inverse_transform(scaled_df), columns=df_x.columns)

# %% [markdown]
# # ***START FROM HERE***

# %% [markdown]
# # ***Making the formula for Models***

# %% [markdown]
# Random Forest without optimization

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    df_x,
    df_y,
    test_size=0.3,
    random_state=42)

# Initialize the Random Forest Regressor
model = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Exponentiate the predictions to get them back to the original scale
y_pred_orig = np.exp(y_pred)

# Calculate the MSE using the original HHIncome values
y_test_orig = np.exp(y_test)  # Exponentiate the true log values as well

residuals = y_test_orig - y_pred_orig
# Step 2: Square the residuals
squared_residual = residuals ** 2
# Step 3: Compute the mean of the squared residuals
rf_unioptimized_mse = np.mean(squared_residual)
print(f'Unioptimized Random Forest Mean Squared Error: {rf_unioptimized_mse}')

# Feature importance
feature_importances = pd.Series(model.feature_importances_, index=X_train.columns)
print(feature_importances.sort_values(ascending=False))
# Out:
# Unioptimized Random Forest Mean Squared Error: 31012762.534744173
# PercentPoverty0to17         0.434738
# PercentPovertyAll           0.119288
# PctNonVetsPoor              0.107034
# PovertyRateACS              0.064065
# Ed5CollegePlus_perCapita    0.052093
#                               ...
# AvgNumEmployed2017_2021     0.000217
# NumEmployed2019             0.000207
# TotalEducationAttainment    0.000198
# NumCivLaborforce2018        0.000150
# TotalHouseholds             0.000115
# Length: 98, dtype: float64

# %%
# Feature importance
feature_importances = pd.Series(model.feature_importances_, index=X_train.columns)
sorted_importances = feature_importances.sort_values(ascending=False).head(20)

# Plot feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x=sorted_importances.values, y=sorted_importances.index)
plt.title('Feature Importances')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()

# %% [markdown]
# Random Forest to find the best Parameters

# %%
# Random forests optimization
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
import numpy as np


# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    df_x,
    df_y,
    test_size=0.3,
    random_state=42)
# Grid search method assisted from CHATGPT
param_grid = {
    'n_estimators': [50, 100, 200, 500],
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5, 10]
    # 'min_samples_leaf': [1, 2, 4],
    # 'max_features': ['auto', 'sqrt', 'log2', None, 0.5, 0.7, 0.9],
    # 'bootstrap': [True, False],
    # 'max_samples': [None, 0.5, 0.7, 0.9],
    # 'max_leaf_nodes': [None, 10, 20, 50, 100],
    # 'min_weight_fraction_leaf': [0.0, 0.1, 0.2],
    # 'oob_score': [True, False],
    # 'warm_start': [True, False]
}

# Initialize the Random Forest Regressor
model = RandomForestRegressor(n_estimators = 100, max_depth = 20, min_samples_leaf = 2, min_samples_split = 5, random_state=42)

# Grid Search with progress update
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1, verbose=2)

# Fit the model
grid_search.fit(X_train, y_train)

# Get the best parameters and the best score
best_params = grid_search.best_params_
best_score = -grid_search.best_score_  # Negate because GridSearchCV uses negative MSE

print(f'Best Parameters: {best_params}')
print(f'Best Score (MSE): {best_score}')

### End of grid search
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] END .max_depth=10, min_samples_split=2, n_estimators=50; total time=   3.4s
# [CV] END .max_depth=10, min_samples_split=2, n_estimators=50; total time=   3.5s
# [CV] END .max_depth=10, min_samples_split=2, n_estimators=50; total time=   3.5s
# [CV] END .max_depth=10, min_samples_split=2, n_estimators=50; total time=   3.5s
# [CV] END .max_depth=10, min_samples_split=2, n_estimators=50; total time=   3.5s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   6.8s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   6.9s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   6.9s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   7.0s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   7.4s
# [CV] END .max_depth=10, min_samples_split=5, n_estimators=50; total time=   3.4s
# [CV] END .max_depth=10, min_samples_split=5, n_estimators=50; total time=   3.4s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=200; total time=  13.8s
# [CV] END .max_depth=10, min_samples_split=5, n_estimators=50; total time=   3.5s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=200; total time=  13.7s
# [CV] END .max_depth=10, min_samples_split=5, n_estimators=50; total time=   3.5s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=200; total time=  13.5s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=200; total time=  13.6s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=200; total time=  13.8s
# [CV] END .max_depth=10, min_samples_split=5, n_estimators=50; total time=   3.5s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=100; total time=   6.8s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=100; total time=   6.9s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=100; total time=   6.7s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=100; total time=   6.6s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=100; total time=   6.6s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=200; total time=  13.2s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=200; total time=  13.6s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=200; total time=  13.1s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=200; total time=  13.2s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=200; total time=  13.4s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=500; total time=  33.5s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=500; total time=  33.6s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=500; total time=  33.4s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=50; total time=   3.4s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=500; total time=  34.2s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=500; total time=  34.1s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=100; total time=   6.5s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=100; total time=   6.4s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=100; total time=   6.5s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=100; total time=   6.4s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=100; total time=   6.7s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=200; total time=  12.7s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=200; total time=  12.9s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=500; total time=  33.3s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=500; total time=  33.3s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=200; total time=  13.0s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=200; total time=  12.6s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=200; total time=  13.1s
# [CV] END .max_depth=20, min_samples_split=2, n_estimators=50; total time=   3.7s
# [CV] END .max_depth=20, min_samples_split=2, n_estimators=50; total time=   3.9s
# [CV] END .max_depth=20, min_samples_split=2, n_estimators=50; total time=   3.8s
# [CV] END .max_depth=20, min_samples_split=2, n_estimators=50; total time=   3.9s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=500; total time=  33.5s
# [CV] END .max_depth=20, min_samples_split=2, n_estimators=50; total time=   3.8s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=500; total time=  34.1s
# [CV] END max_depth=10, min_samples_split=5, n_estimators=500; total time=  33.6s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=100; total time=   7.6s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=100; total time=   7.5s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=100; total time=   7.5s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=100; total time=   7.5s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=100; total time=   7.4s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=500; total time=  32.0s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=500; total time=  32.4s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=200; total time=  14.6s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=200; total time=  14.9s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=200; total time=  15.0s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=200; total time=  15.1s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=200; total time=  14.6s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=500; total time=  32.0s
# [CV] END .max_depth=20, min_samples_split=5, n_estimators=50; total time=   3.6s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=500; total time=  32.6s
# [CV] END .max_depth=20, min_samples_split=5, n_estimators=50; total time=   3.7s
# [CV] END .max_depth=20, min_samples_split=5, n_estimators=50; total time=   3.7s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=500; total time=  32.6s
# [CV] END .max_depth=20, min_samples_split=5, n_estimators=50; total time=   3.7s
# [CV] END .max_depth=20, min_samples_split=5, n_estimators=50; total time=   3.7s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=100; total time=   7.3s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=100; total time=   7.3s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=100; total time=   7.5s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=100; total time=   7.2s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=100; total time=   7.6s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=200; total time=  14.5s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=200; total time=  14.8s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=200; total time=  14.6s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=500; total time=  36.6s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=500; total time=  37.1s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=200; total time=  14.9s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=200; total time=  14.8s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=50; total time=   3.4s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=50; total time=   3.4s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=50; total time=   3.7s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=50; total time=   3.4s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=500; total time=  36.9s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=500; total time=  37.5s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=500; total time=  37.7s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=100; total time=   6.7s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=100; total time=   7.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=100; total time=   7.3s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=100; total time=   7.0s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=100; total time=   6.8s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=200; total time=  13.8s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=200; total time=  14.0s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=200; total time=  13.7s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=200; total time=  13.9s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=500; total time=  36.3s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=500; total time=  36.8s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=200; total time=  13.9s
# [CV] END .max_depth=30, min_samples_split=2, n_estimators=50; total time=   3.6s
# [CV] END .max_depth=30, min_samples_split=2, n_estimators=50; total time=   3.6s
# [CV] END .max_depth=30, min_samples_split=2, n_estimators=50; total time=   3.8s
# [CV] END .max_depth=30, min_samples_split=2, n_estimators=50; total time=   3.8s
# [CV] END .max_depth=30, min_samples_split=2, n_estimators=50; total time=   3.7s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=500; total time=  36.5s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=500; total time=  36.8s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=100; total time=   7.3s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=100; total time=   7.3s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=500; total time=  36.8s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=100; total time=   7.6s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=100; total time=   7.7s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=100; total time=   7.5s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=200; total time=  15.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=500; total time=  34.0s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=500; total time=  34.7s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=200; total time=  14.8s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=200; total time=  14.8s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=200; total time=  14.9s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=200; total time=  15.1s
# [CV] END .max_depth=30, min_samples_split=5, n_estimators=50; total time=   3.6s
# [CV] END .max_depth=30, min_samples_split=5, n_estimators=50; total time=   3.6s
# [CV] END .max_depth=30, min_samples_split=5, n_estimators=50; total time=   3.6s
# [CV] END .max_depth=30, min_samples_split=5, n_estimators=50; total time=   3.8s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=500; total time=  35.0s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=500; total time=  35.2s
# [CV] END .max_depth=30, min_samples_split=5, n_estimators=50; total time=   3.8s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=500; total time=  34.7s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=100; total time=   7.3s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=100; total time=   7.2s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=100; total time=   7.5s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=100; total time=   7.2s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=100; total time=   7.5s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=200; total time=  14.6s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=200; total time=  14.7s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=200; total time=  14.6s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=500; total time=  37.3s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=500; total time=  37.2s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=200; total time=  15.0s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=200; total time=  14.5s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=50; total time=   3.4s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=50; total time=   3.4s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=50; total time=   3.5s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=50; total time=   3.5s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=50; total time=   3.4s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=500; total time=  37.1s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=500; total time=  37.4s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=500; total time=  37.6s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=100; total time=   7.0s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=100; total time=   6.8s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=100; total time=   7.0s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=100; total time=   7.0s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=100; total time=   7.0s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=200; total time=  13.7s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=200; total time=  13.4s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=200; total time=  13.9s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=500; total time=  36.5s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=200; total time=  14.3s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=500; total time=  36.6s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=200; total time=  14.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=50; total time=   3.7s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=50; total time=   3.8s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=50; total time=   4.0s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=50; total time=   3.8s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=500; total time=  36.2s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=50; total time=   3.8s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=500; total time=  36.7s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=100; total time=   7.3s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=100; total time=   7.4s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=500; total time=  37.1s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=100; total time=   7.4s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=100; total time=   7.5s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=100; total time=   7.5s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=200; total time=  14.8s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=500; total time=  34.9s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=500; total time=  34.7s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=200; total time=  14.7s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=200; total time=  14.9s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=200; total time=  14.9s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=200; total time=  15.2s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=50; total time=   3.6s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=50; total time=   3.6s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=50; total time=   3.6s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=50; total time=   3.8s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=500; total time=  34.1s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=500; total time=  34.8s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=50; total time=   3.6s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=500; total time=  34.8s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=100; total time=   7.3s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=100; total time=   7.2s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=100; total time=   7.3s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=100; total time=   7.5s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=100; total time=   7.4s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=200; total time=  15.2s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=200; total time=  15.0s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=500; total time=  36.7s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=500; total time=  37.3s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=200; total time=  14.8s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=200; total time=  15.2s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=200; total time=  14.8s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=50; total time=   3.4s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=50; total time=   3.4s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=50; total time=   3.5s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=500; total time=  37.0s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=500; total time=  37.5s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=100; total time=   6.9s
# [CV] END max_depth=None, min_samples_split=2, n_estimators=500; total time=  37.6s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=100; total time=   6.9s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=100; total time=   6.8s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=100; total time=   6.8s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=100; total time=   6.7s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=200; total time=  13.7s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=500; total time=  36.2s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=200; total time=  13.5s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=500; total time=  35.8s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=200; total time=  13.8s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=200; total time=  13.8s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=200; total time=  13.7s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=500; total time=  34.5s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=500; total time=  34.7s
# [CV] END max_depth=None, min_samples_split=5, n_estimators=500; total time=  34.0s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=500; total time=  29.5s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=500; total time=  29.4s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=500; total time=  27.7s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=500; total time=  28.0s
# [CV] END max_depth=None, min_samples_split=10, n_estimators=500; total time=  28.1s
# Best Parameters: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 500}
# Best Score (MSE): 0.008455415465239865

# %% [markdown]
# Best Parameters: {'max_features': 0.7, 'min_samples_leaf': 1, 'min_samples_split': 2}{'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 500}
#
# Best Score (MSE): 0.008433715431085337

# %% [markdown]
# Random Forest with fitting the best parameters

# %% [markdown]
# (n_estimators = 100, max_depth = 20, min_samples_leaf = 2, min_samples_split = 5, max_features = 0.5, random_state=42)

# %%
model2 = RandomForestRegressor(n_estimators = 500, max_depth = 20, min_samples_leaf = 1, min_samples_split = 2, max_features = 0.7, random_state=42)
model2.fit(X_train, y_train)
y_pred_log = model2.predict(X_test)

# Exponentiate the predictions to get them back to the original scale
y_pred_original = np.exp(y_pred_log)

# Calculate the MSE using the original HHIncome values
y_test_original = np.exp(y_test)  # Exponentiate the true log values as well

residuals = y_test_original - y_pred_original
# Step 2: Square the residuals
squared_residuals = residuals ** 2
# Step 3: Compute the mean of the squared residuals
rf_mse = np.mean(squared_residuals)
print(f'Mean Squared Error: {rf_mse}')
# Feature importance
feature_importances = pd.Series(model2.feature_importances_, index=X_train.columns)
print(feature_importances.sort_values(ascending=False))
# Out:
# Mean Squared Error: 30363877.203336883
# PercentPoverty0to17          0.338666
# PercentPovertyAll            0.158682
# PctNonVetsPoor               0.109488
# PovertyRateACS               0.102187
# Ed5CollegePlus_perCapita     0.060966
#                                ...
# TotalOccupiedHousingUnits    0.000271
# CivPop18ONum                 0.000266
# AvgNumEmployed2017_2021      0.000252
# TotalHouseholds              0.000223
# TotalPopulation25Plus        0.000221
# Length: 99, dtype: float64

# %% [markdown]
# XGBooost to find the best Parameters

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    df_x,
    df_y,
    test_size=0.3,
    random_state=42)

# Grid search method assisted from CHATGPT
param_grid = {
    # 'n_estimators': [50, 100, 200],
    # 'max_depth': [3, 6, 9],
    # 'learning_rate': [0.01, 0.1, 0.2]
    #'subsample': [0.8, 0.9, 1.0],
    #'colsample_bytree': [0.8, 0.9, 1.0],
    #'gamma': [0, 0.1, 0.2],
    #'min_child_weight': [1, 5, 10]
}
# # Initialize the XGBoost Regressor
xgboost_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)
grid_search = GridSearchCV(
    estimator=xgboost_model,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',  # Use 'accuracy' for classification
    cv=5,  # Number of cross-validation folds
    n_jobs=-1,# Use all available cores
    verbose=3
)
# Fit GridSearchCV
grid_search.fit(X_train, y_train)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = -grid_search.best_score_  # Negative MSE because GridSearchCV uses negative scoring

print(f'Best Parameters: {best_params}')
print(f'Best Score (MSE): {best_score}')

### End of GRID SEARCH
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END .................................., score=-0.009 total time=   1.0s
# [CV 3/5] END .................................., score=-0.008 total time=   1.0s
# [CV 4/5] END .................................., score=-0.009 total time=   1.0s
# [CV 5/5] END .................................., score=-0.008 total time=   1.1s
# [CV 2/5] END .................................., score=-0.010 total time=   1.1s
# Best Parameters: {}
# Best Score (MSE): 0.00876714763900257

# %% [markdown]
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
#
# Best Score (MSE): 0.0077136019762604315

# %% [markdown]
# XGBoost with fitting the best Parameters

# %%
# # Fit the model
xgboost_model2 = xgb.XGBRegressor(objective='reg:squarederror', n_estimators = 200, max_depth = 3, learning_rate = 0.1, random_state=42)
xgboost_model2.fit(X_train, y_train)

# # # Make predictions on the log scale
y_pred_log = xgboost_model2.predict(X_test)

# # # Exponentiate the predictions to get them back to the original scale
y_pred_original = np.exp(y_pred_log)

# # # Calculate the MSE using the original HHIncome values
y_test_original = np.exp(y_test)

residuals = y_test_original - y_pred_original
# Step 2: Square the residuals
squared_residuals = residuals ** 2
# # Step 3: Compute the mean of the squared residuals
xgb_mse = np.mean(squared_residuals)
print(f'Mean Squared Error: {xgb_mse}')

# # Feature importance
feature_importances = pd.Series(xgboost_model2.feature_importances_, index=X_train.columns)
print(feature_importances.sort_values(ascending=False))
# Out:
# Mean Squared Error: 25568880.28000386
# PercentPoverty0to17         0.198758
# HomeOwnership_Education     0.121333
# PctNonVetsPoor              0.112117
# PercentPovertyAll           0.099324
# Ed5CollegePlus_perCapita    0.062416
#                               ...
# NumEmployed2017             0.000000
# NumEmployed2018             0.000000
# TotalEducationAttainment    0.000000
# NumEmployed2021             0.000000
# NumEmployed2020             0.000000
# Length: 98, dtype: float32

# %% [markdown]
# Ridge Model

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import RidgeCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    df_x,
    df_y,
    test_size=0.3,
    random_state=42)

# Define a range of alphas to search
alpha_range = np.logspace(-4, 4, 100)

# Initialize RidgeCV with cross-validation, removing store_cv_values
ridge_cv = RidgeCV(alphas=alpha_range, cv=5) # Remove store_cv_values=True

# Fit the model on the training data
ridge_cv.fit(X_train, y_train)

# Best alpha value
best_alpha = ridge_cv.alpha_
print(f'Best Alpha: {best_alpha}')

# Make predictions on the log scale using the best model
y_pred_log = ridge_cv.predict(X_test)

# Exponentiate the predictions to get them back to the original scale
y_pred_original = np.exp(y_pred_log)

# Exponentiate the true test values to the original scale
y_test_original = np.exp(y_test)

# Calculate the Mean Squared Error using the original HHIncome values
ridge_mse = mean_squared_error(y_test_original, y_pred_original)
print(f'Mean Squared Error: {ridge_mse}')

# Coefficients of the best model
coefficients = pd.Series(ridge_cv.coef_, index=X_train.columns)
print("Coefficients:")
print(coefficients.sort_values(ascending=False))
# Out:
# Best Alpha: 0.6280291441834259
# Mean Squared Error: 45822572.85945936
# Coefficients:
# Ed5CollegePlus_perCapita    0.256776
# FemaleHHRatio               0.208198
# HomeEduInteraction          0.179770
# AvgHHSize                   0.141088
# Ed4AssocDegree_perCapita    0.104446
#                               ...
# PercentPoverty0to17        -0.010521
# UnempRate2019              -0.018931
# PovertyRateACS             -0.020738
# Ed1LessThanHS_perCapita    -0.100272
# Ed3SomeCollege_perCapita   -0.270759
# Length: 98, dtype: float64

# %% [markdown]
# Lasso Model

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LassoCV

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(['LogHHIncome', 'State'], axis=1),
    df['LogHHIncome'],
    test_size=0.3,
    random_state=42)

# Initialize LassoCV with cross-validation
model = LassoCV(alphas=np.logspace(-4, 4, 100), cv=5)  # Adjust alphas as needed

# Fit the model
model.fit(X_train, y_train)

# Best alpha value
best_alpha = model.alpha_
print(f'Best Alpha: {best_alpha}')

# Make predictions on the log scale using the best model
y_pred_log = model.predict(X_test)

# Exponentiate the predictions to get them back to the original scale
y_pred_original = np.exp(y_pred_log)

# Calculate the MSE using the original HHIncome values
y_test_original = np.exp(y_test)

residuals = y_test_original - y_pred_original
# Step 2: Square the residuals
squared_residuals = residuals ** 2
# Step 3: Compute the mean of the squared residuals
lasso_mse = np.mean(squared_residuals)
print(f'Mean Squared Error with Best Alpha: {lasso_mse}')

# Coefficients of the best model
coefficients = pd.Series(model.coef_, index=X_train.columns)
print(coefficients.sort_values(ascending=False))
# Out:
# Best Alpha: 0.0001
# Mean Squared Error with Best Alpha: 28940491.361871433
# Ed5CollegePlus_perCapita    0.256507
# HomeEduInteraction          0.165321
# AvgHHSize                   0.144444
# FemaleHHRatio               0.106592
# ForeignBornHHRatio          0.046735
#                               ...
# PctNonVetsDisabilty        -0.004871
# PercentPoverty0to17        -0.009894
# UnempRate2019              -0.019093
# PovertyRateACS             -0.021132
# Ed3SomeCollege_perCapita   -0.237354
# Length: 99, dtype: float64

# %% [markdown]
# Ploting the Graphs

# %%
import matplotlib.pyplot as plt
# Data for the bar chart
models = ['Unoptimized Random Forest', 'Random Forest', 'XGBoost', 'Ridge', 'Lasso']
mse_values = [rf_unioptimized_mse, rf_mse, xgb_mse, ridge_mse, lasso_mse]

# Create a color palette
colors = sns.color_palette("viridis", len(models))

# Create the bar chart with Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x=models, y=mse_values, palette=colors)

# Add labels and title
plt.xlabel('Model', fontsize=12)
plt.ylabel('Mean Squared Error', fontsize=12)
plt.title('Comparison of Mean Squared Errors for Different Models', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Annotate bars with MSE values
for i, v in enumerate(mse_values):
    plt.text(i, v, f"{v:.2f}", ha='center', va='bottom', fontsize=10)

# Add grid lines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Remove top and right spines for a cleaner look
sns.despine()

# Display the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# # K-Means Clustering
# Trying to do clustring

# %%
from sklearn.cluster import KMeans
# Assuming 'scaled_df' is your DataFrame with relevant features
# Select features for clustering (replace with your actual feature names)
features_for_clustering = ['Ed1LessThanHS_perCapita', 'Ed2HSDiplomaOnly_perCapita',
                           'Ed3SomeCollege_perCapita', 'Ed4AssocDegree_perCapita',
                           'Ed5CollegePlus_perCapita', 'PercentPoverty0to17',
                           'PovertyRateACS', 'PercentPovertyAll', 'AvgHHSize',
                           'FemaleHHRatio', 'ForeignBornRatio', 'OwnHomeRatio', 
                           'PctEmpServices'
                           ]

X = clean_df[features_for_clustering]

# Determine optimal number of clusters using the Elbow method
inertia = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 11), inertia, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.show()

# Choose optimal k based on the Elbow method (let's assume k=4)
optimal_k = 3

# Apply K-means clustering
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
scaled_df['Cluster'] = kmeans.fit_predict(X)

# Analyze cluster characteristics (example: mean values of features per cluster)
cluster_means = scaled_df.groupby('Cluster')[features_for_clustering].mean()
print(cluster_means)

# Visualize clusters (example using scatter plot for two features)
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Ed5CollegePlus_perCapita', y='PercentPoverty0to17', hue='Cluster', data=scaled_df, palette='viridis')
plt.title('K-means Clustering: Education vs. PercentPoverty0to17')
plt.xlabel('Percentage with College Degree or Higher')
plt.ylabel('Poverty Rate 0 to 17')
plt.show()

# Further visualizations and analysis can be done based on cluster characteristics
# For example, you can create boxplots, histograms, or other relevant plots
# to explore the distribution of different features within each cluster.
# Out:
#          Ed1LessThanHS_perCapita  Ed2HSDiplomaOnly_perCapita  \
# Cluster
# 0                       1.184387                    0.521415
# 1                      -0.570666                   -0.365712
# 2                       0.200287                    0.214668
#
#          Ed3SomeCollege_perCapita  Ed4AssocDegree_perCapita  \
# Cluster
# 0                       -0.328781                 -0.567741
# 1                        0.072162                  0.341748
# 2                        0.039704                 -0.171361
#
#          Ed5CollegePlus_perCapita  PercentPoverty0to17  PovertyRateACS  \
# Cluster
# 0                       -0.784578             1.737685        1.668055
# 1                        0.477562            -0.834848       -0.762236
# 2                       -0.242654             0.291189        0.236254
#
#          PercentPovertyAll  AvgHHSize  FemaleHHRatio  ForeignBornRatio  \
# Cluster
# 0                 1.756863   0.481749       1.273697         -0.270832
# 1                -0.797553  -0.068138      -0.510855          0.159378
# 2                 0.243014  -0.099720       0.101756         -0.077715
#
#          OwnHomeRatio  PctEmpServices
# Cluster
# 0           -0.440934       -0.066718
# 1            0.219228       -0.036672
# 2           -0.082051        0.064757

# %%
# Based on the dendrogram, assume you have selected these features for clustering
selected_features = [
    'Ed5CollegePlus_perCapita',  # Representative feature for education level
    'PovertyRateACS',            # Poverty rate
    'ForeignBornRatio',          # Foreign-born population ratio
    'OwnHomeRatio',              # Homeownership ratio
    'PctEmpServices'             # Employment in services sector
]

X = clean_df[selected_features]

# Standardize the data (important for K-means)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Determine optimal number of clusters using the Elbow method
inertia = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 11), inertia, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.show()

# Choose optimal k based on the Elbow method (let's assume k=4)
optimal_k = 3

# Apply K-means clustering
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
clean_df['Cluster'] = kmeans.fit_predict(X_scaled)

# Analyze cluster characteristics (example: mean values of features per cluster)
cluster_means = clean_df.groupby('Cluster')[selected_features].mean()
print(cluster_means)

# Visualize clusters (example using scatter plot for two features)
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Ed5CollegePlus_perCapita', y='PercentPoverty0to17', hue='Cluster', data=clean_df, palette='viridis')
plt.title('K-means Clustering: Education vs. PercentPoverty0to17')
plt.xlabel('Percentage with College Degree or Higher')
plt.ylabel('Poverty Rate 0 to 17')
plt.show()
# Out:
#          Ed5CollegePlus_perCapita  PovertyRateACS  ForeignBornRatio  \
# Cluster
# 0                        0.164878       21.084573          0.031692
# 1                        0.214318       11.502847          0.033060
# 2                        0.373525       12.073457          0.108965
#
#          OwnHomeRatio  PctEmpServices
# Cluster
# 0            0.696037       43.383396
# 1            0.770427       40.569206
# 2            0.649556       51.020130
